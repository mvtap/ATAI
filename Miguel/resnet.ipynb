# %%
# organize dataset into a useful structure
from os import makedirs
from os import listdir
from shutil import move, copy
from random import seed
from random import random

# %%
seed(1)
# define ratio of pictures to use for validation
val_ratio = 0.10
# copy training dataset images into subdirectories
src_directory = 'dogs-vs-cats-resnet/train'
for file in listdir(src_directory):
	src = src_directory + '/' + file
	if random() < val_ratio:
		dst = 'dogs-vs-cats-resnet/val'
		move(src, dst)

# %%
# !python3 prepro.py --dataset-path dogs-vs-cats-resnet
# Out:
# 2021-12-30 01:38:54.569029: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# hello
# INFO Done preprocessing!

# %%
# !python3 train.py -lr 0.005 --num-epochs 10 --batch-size 8 --save-every 5 --tensorboard-vis --print-summary
# Out:
# 2021-12-30 02:17:04.782601: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-30 02:17:05.775022: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-30 02:17:05.775213: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-30 02:17:05.775849: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-12-30 02:17:05.798498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
